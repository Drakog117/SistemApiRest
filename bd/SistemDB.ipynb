-- %% [markdown]
-- # [SistemDB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [SistemDB]    Script Date: 11/09/2024 07:48:59 a. m. ******/
CREATE DATABASE [SistemDB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'SistemDB', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\SistemDB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'SistemDB_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\SistemDB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [SistemDB] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [SistemDB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [SistemDB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [SistemDB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [SistemDB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [SistemDB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [SistemDB] SET ARITHABORT OFF 
GO
ALTER DATABASE [SistemDB] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [SistemDB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [SistemDB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [SistemDB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [SistemDB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [SistemDB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [SistemDB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [SistemDB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [SistemDB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [SistemDB] SET  DISABLE_BROKER 
GO
ALTER DATABASE [SistemDB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [SistemDB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [SistemDB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [SistemDB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [SistemDB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [SistemDB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [SistemDB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [SistemDB] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [SistemDB] SET  MULTI_USER 
GO
ALTER DATABASE [SistemDB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [SistemDB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [SistemDB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [SistemDB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [SistemDB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [SistemDB] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [SistemDB] SET QUERY_STORE = ON
GO
ALTER DATABASE [SistemDB] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[code_bar_seq]

-- %%
USE [SistemDB]
GO

-- %%
USE [SistemDB]
GO
/****** Object:  Sequence [dbo].[code_bar_seq]    Script Date: 11/09/2024 07:48:59 a. m. ******/
CREATE SEQUENCE [dbo].[code_bar_seq] 
 AS [bigint]
 START WITH 1
 INCREMENT BY 50
 MINVALUE -9223372036854775808
 MAXVALUE 9223372036854775807
 CACHE 
GO

-- %% [markdown]
-- # [dbo].[system_user_seq]

-- %%
USE [SistemDB]
GO
/****** Object:  Sequence [dbo].[system_user_seq]    Script Date: 11/09/2024 07:48:59 a. m. ******/
CREATE SEQUENCE [dbo].[system_user_seq] 
 AS [bigint]
 START WITH 1
 INCREMENT BY 50
 MINVALUE -9223372036854775808
 MAXVALUE 9223372036854775807
 CACHE 
GO

-- %% [markdown]
-- # [dbo].[system_users_seq]

-- %%
USE [SistemDB]
GO
/****** Object:  Sequence [dbo].[system_users_seq]    Script Date: 11/09/2024 07:48:59 a. m. ******/
CREATE SEQUENCE [dbo].[system_users_seq] 
 AS [bigint]
 START WITH 1
 INCREMENT BY 50
 MINVALUE -9223372036854775808
 MAXVALUE 9223372036854775807
 CACHE 
GO

-- %% [markdown]
-- # [dbo].[user_seq]

-- %%
USE [SistemDB]
GO
/****** Object:  Sequence [dbo].[user_seq]    Script Date: 11/09/2024 07:48:59 a. m. ******/
CREATE SEQUENCE [dbo].[user_seq] 
 AS [bigint]
 START WITH 1
 INCREMENT BY 50
 MINVALUE -9223372036854775808
 MAXVALUE 9223372036854775807
 CACHE 
GO

-- %% [markdown]
-- # [dbo].[code_bar]

-- %%
/****** Object:  Table [dbo].[code_bar]    Script Date: 11/09/2024 07:48:59 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[code_bar](
	[id_code] [int] IDENTITY(1,1) NOT NULL,
	[name_bar_code] [varchar](255) NULL,
	[id_user] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id_code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[products]

-- %%
/****** Object:  Table [dbo].[products]    Script Date: 11/09/2024 07:48:59 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[products](
	[id_product] [int] IDENTITY(1,1) NOT NULL,
	[name_product] [varchar](255) NULL,
	[price_product] [int] NULL,
	[id_user] [int] NULL,
	[unit_product] [int] NULL,
	[id_unit] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id_product] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[units]

-- %%
/****** Object:  Table [dbo].[units]    Script Date: 11/09/2024 07:48:59 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[units](
	[id_unit] [int] IDENTITY(1,1) NOT NULL,
	[name_unit] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[id_unit] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[users]

-- %%
/****** Object:  Table [dbo].[users]    Script Date: 11/09/2024 07:48:59 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[users](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[full_name] [varchar](255) NULL,
	[password] [varchar](255) NULL,
	[phone] [varchar](255) NULL,
	[role] [varchar](255) NULL,
	[username] [varchar](255) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UKr43af9ap4edm43mmtq01oddj6] UNIQUE NONCLUSTERED 
(
	[username] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FKa71jjdsx1jgbanx5rtmenno2k]

-- %%
ALTER TABLE [dbo].[code_bar]  WITH CHECK ADD  CONSTRAINT [FKa71jjdsx1jgbanx5rtmenno2k] FOREIGN KEY([id_user])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[code_bar] CHECK CONSTRAINT [FKa71jjdsx1jgbanx5rtmenno2k]
GO

-- %% [markdown]
-- # [FK7i9mmv01y8nx97ehjomu440xd]

-- %%
ALTER TABLE [dbo].[products]  WITH CHECK ADD  CONSTRAINT [FK7i9mmv01y8nx97ehjomu440xd] FOREIGN KEY([id_user])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[products] CHECK CONSTRAINT [FK7i9mmv01y8nx97ehjomu440xd]
GO

-- %% [markdown]
-- # [FKsums02yb5gvsif2quesalfk4t]

-- %%
ALTER TABLE [dbo].[products]  WITH CHECK ADD  CONSTRAINT [FKsums02yb5gvsif2quesalfk4t] FOREIGN KEY([id_unit])
REFERENCES [dbo].[units] ([id_unit])
GO
ALTER TABLE [dbo].[products] CHECK CONSTRAINT [FKsums02yb5gvsif2quesalfk4t]
GO

-- %% [markdown]
-- # [CK__users__role__3D2915A8]

-- %%
ALTER TABLE [dbo].[users]  WITH CHECK ADD CHECK  (([role]='USER' OR [role]='ADMIN'))
GO

-- %% [markdown]
-- # [dbo].[Catalog_Units]

-- %%
/****** Object:  StoredProcedure [dbo].[Catalog_Units]    Script Date: 11/09/2024 07:48:59 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [dbo].[Catalog_Units] 

	@IdUser        INT
AS
BEGIN
    BEGIN TRY
        -- Insertar el nuevo cliente en la tabla
        SELECT * 
		  FROM units
    END TRY
    BEGIN CATCH
        -- Capturar el error
        DECLARE @ErrorMessage NVARCHAR(4000), @ErrorSeverity INT, @ErrorState INT;
        
        SELECT
            @ErrorMessage = ERROR_MESSAGE(),
            @ErrorSeverity = ERROR_SEVERITY(),
            @ErrorState = ERROR_STATE();
        
        -- Mostrar el error al usuario
        RAISERROR (@ErrorMessage, @ErrorSeverity, @ErrorState);
    END CATCH
END
GO

-- %% [markdown]
-- # [dbo].[Catalog_Users]

-- %%
/****** Object:  StoredProcedure [dbo].[Catalog_Users]    Script Date: 11/09/2024 07:48:59 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,JVALENCIA>
-- Create date: <Create Date,31/08/2024,>
-- Description:	<Description, CATALOGO DE USUARIOS,>
-- =============================================
CREATE PROCEDURE [dbo].[Catalog_Users] 

	@IdUser        INT
AS
BEGIN
    BEGIN TRY
        -- Insertar el nuevo cliente en la tabla
        SELECT id,
			   username,
			   full_name,
			   phone
		  FROM users
    END TRY
    BEGIN CATCH
        -- Capturar el error
        DECLARE @ErrorMessage NVARCHAR(4000), @ErrorSeverity INT, @ErrorState INT;
        
        SELECT
            @ErrorMessage = ERROR_MESSAGE(),
            @ErrorSeverity = ERROR_SEVERITY(),
            @ErrorState = ERROR_STATE();
        
        -- Mostrar el error al usuario
        RAISERROR (@ErrorMessage, @ErrorSeverity, @ErrorState);
    END CATCH
END
GO

-- %% [markdown]
-- # [dbo].[Store_BarCode]

-- %%
/****** Object:  StoredProcedure [dbo].[Store_BarCode]    Script Date: 11/09/2024 07:48:59 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [dbo].[Store_BarCode] 
	@NameBarCode   Varchar(250),
	@IdUser        INT
AS
BEGIN
    BEGIN TRY
        -- Insertar el nuevo cliente en la tabla
        INSERT INTO Code_bar(name_bar_code, id_user)
        VALUES ( @NameBarCode, @IdUser);
    END TRY
    BEGIN CATCH
        -- Capturar el error
        DECLARE @ErrorMessage NVARCHAR(4000), @ErrorSeverity INT, @ErrorState INT;
        
        SELECT
            @ErrorMessage = ERROR_MESSAGE(),
            @ErrorSeverity = ERROR_SEVERITY(),
            @ErrorState = ERROR_STATE();
        
        -- Mostrar el error al usuario
        RAISERROR (@ErrorMessage, @ErrorSeverity, @ErrorState);
    END CATCH
END
GO

-- %% [markdown]
-- # [dbo].[Store_Products]

-- %%
/****** Object:  StoredProcedure [dbo].[Store_Products]    Script Date: 11/09/2024 07:48:59 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [dbo].[Store_Products] 
	@NameProduct   VARCHAR(250),
	@PriceProduct  INT,
	@IdUnitProduct INT,
	@IdUser        INT
AS
BEGIN
    BEGIN TRY
        -- Insertar el nuevo cliente en la tabla
        INSERT INTO Produts(@NameProduct, @PriceProduct,@IdUnitProduct,@IdUser)
        VALUES ( @NameProduct, @PriceProduct,@IdUnitProduct,@IdUser);
    END TRY
    BEGIN CATCH
        -- Capturar el error
        DECLARE @ErrorMessage NVARCHAR(4000), @ErrorSeverity INT, @ErrorState INT;
        
        SELECT
            @ErrorMessage = ERROR_MESSAGE(),
            @ErrorSeverity = ERROR_SEVERITY(),
            @ErrorState = ERROR_STATE();
        
        -- Mostrar el error al usuario
        RAISERROR (@ErrorMessage, @ErrorSeverity, @ErrorState);
    END CATCH
END
GO

-- %% [markdown]
-- # [SistemDB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [SistemDB] SET  READ_WRITE 
GO
